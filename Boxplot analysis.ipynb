# %% [markdown]
# - Summarise the history of the box plot and situations in which it used.
# - Demonstrate the use of the box plot using data of your choosing.
# - Explain any relevant terminology such as the terms quartile and percentile.
# - Compare the box plot to alternatives.

# %% [markdown]
# ## Boxplot. History and analysis
#
# Boxplots have been used for more than 40 years to represent data distributions, helping researchers and students to explore and understand data from a different approach to other existing methods.
#
# When we first approach a data set we tend to make descriptive approximations to obtain a first impression of the dimensions of our data. However, as we have already seen in previous projects, these approaches could be misleading when dealing with some specific distributions (ie, ouliers that interfere in the result of descriptive calculations, distorting the numerical results).
#
# Boxplots help represent both the quartilic distribution, central tendency and ouliers for our data sets.
#
# We owe this useful resource to statician John Wilder Tukey (1915-2000), who invented this graph in the 1970s, before using computer-generated graphical assistance, since they were hand-drawn at its origin.
#
# As stated by [Encyclopaedia Britannica](https://www.britannica.com/science/box-and-whisker-plot):
#
# *Box-and-whisker plot, also called boxplot or box plot, graph that summarizes numerical data based on quartiles, which divide a data set into fourths. The box-and-whisker plot is useful for revealing the central tendency and variability of a data set, the distribution (particularly symmetry or skewness) of the data, and the presence of outliers. It is also a powerful graphical technique for comparing samples from two or more different treatments or populations. It was invented in the 1970s by American statistician John Wilder Tukey.*
#
# According to Hadley Wickham and Lisa Stryjewski in their 2011 paper [40 years of boxplots](http://vita.had.co.nz/papers/boxplots.pdf), "*the boxplot has become one of the most frequently used statistical graphics,
# and is one of the few plot types invented in the 20th century that has found widespread adoption. Due to
# their elegance and practicality, boxplots have spawned a wealth of variations and enhancement.*"

# %% [markdown]
# ![40-years-of-boxplots.png](attachment:40-years-of-boxplots.png)

# %% [markdown]
# ## Description
#
# The box plot is a standardised way of displaying the distribution of data based on the 'five number summary':
# - minimum
# - first quartile
# - median
# - third quartile
# - maximum
#
# ### Median vs Average
#
# Given a variable, there are some baasic measures that can characterise its distribution. The **median** represents the point in the distribution, when sorted from lowest to highest values, where half of the values are above and half are below. This differs from the **average**,although both are considered central tendency measures. While average is calculated by adding all values together and dividing the result by the number of values, the median only takes in account the **number of values** in the variable. In a set of 11 values, once sorted form lowest to highest, median will always be the sixth value, leaving 5 below and 5 above it, regardless of which are these values.
#
# In the case of a distribution with an even number of values, median will be calculated as the point between the two central values (ie. If the distribution has 10 values, median would be the average value between fifth and sixth values).

# %%
import numpy as np
# Generating a list of 11 integers
x=np.random.randint(1,500, 11)
print (x)
# Sorting list
x.sort()
print(x)
print('Median is',x[5])
avg=sum(x)/len(x)
print('Average is',avg)
# Out:
# [171 173 206  48 321 295 340  19 140 176 366]
# [ 19  48 140 171 173 176 206 295 321 340 366]
# Median is 176
# Average is 205.0

# %% [markdown]
# ### Quartiles and Percentiles
#
# Similarly, quartiles divide a rank-ordered data set into four equal parts. The values that divide each part are called the first, second, and third quartiles; and they are denoted by Q1, Q2, and Q3, respectively. And percentiles divide this same data into 100 equal parts. Therefore, Q1 equals to Percentile 25, Q2 equals to Percentile 50 (and, consequently, to Median) and Q3 equals to Percentile 75.
#
# ## Boxplot layout and characteristics
#
# In the simplest box plot the central rectangle spans the first quartile to the third quartile (the interquartile range). A segment inside the rectangle shows the median and "whiskers" above and below the box show the locations of the minimum and maximum.
#
# Therefore, this simple plot comprises in a very simple way some of the main characteristics needed for exploratory tasks in statistical analysis.
#
# The box part of this plot displays the **full variation range** for a variable from minimum to maximum, the **variation range** as per the interquartile range and the **most typical value** (the median, represented by the line within the box).
#
# ![box-plot-explained.gif](attachment:box-plot-explained.gif)
#
# In a previous project, as part of Fundamentals of Data Analysis module, analysing [Ascombe's Quartet](https://github.com/Luis-Navarro/Python-Fundamentals/blob/master/Anscombe.ipynb) the importance of exploring and representing statistics graphically was already stated. In fact, Ascombe insisted in the equal importance of analysis and graphical representation to avoid misinterpretations of data that would lead to inaccurate conclussions. Let's quote again Ascombe to stress the importance granted to full-range exploratory analysis in this binomial aspect of calculations and plots:
#
# >>_***"A computer should make both calculations and graphs. Both sorts of output should be studied; each will contribute to understanding."***
#
# It is to note that both Ascombe and Tukey were developing their main works during the same period, in which computer-based statitical analysis was in its initial stage. Both statisticians perceived that some basic features needed to be established in order to chanel the imminent technical expansion granted by computing, which would accelerate statistical analysis scope, but could also multiply misinterpretations if foundations and good statistical practises were not clarified.
#
# ### Outliers
#
# Furthermore, another sometimes crucial characteristic is also represented in boxplots. **Outliers**, defined as an extreme value that differs greatly from other values in a set of values, are also represented as values that are at least 1.5 interquartile ranges below the first quartile (Q1), or at least 1.5 interquartile ranges above the third quartile (Q3). Definition taken from [StatsTrek](https://stattrek.com/statistics/dictionary.aspx?definition=Outlier)
#
# ![complex.box.defs.gif](attachment:complex.box.defs.gif)
#
# Outliers may mislead statistical interpretations when not taken in account, since these values that lie outside the overall pattern of a distribution might cause an error of measurement due to these extreme values leading to an underestimation or overstimation when not identified. Spotting these inusual values can be very insightful for further analysis and they can cause painful consequences for the unaware researcher's analysis.
#
# ### Skewness
#
# As defined by [StatsTrek](https://stattrek.com/statistics/dictionary.aspx?definition=skewness), when they are displayed graphically, some distributions of data have many more observations on one side of the graph than the other.
#
# Distributions with fewer observations on the right (toward higher values) are said to be skewed right; and distributions with fewer observations on the left (toward lower values) are said to be skewed left.
#
# Since boxplots are tools for explore distributions graphically, skewness can be easily spotted, granting more information for the researcher regarding variables and, again, preventing him/her to make fast interpretations of data. Detecting possible skewness in a variable should lead for further investigation, delving into other methods, as explained in [this entry](https://stats.stackexchange.com/questions/96553/how-to-assess-skewness-from-a-boxplot).
#
#
# ## Use of boxplots
#
# Therefore, boxplots are a very useful tool for **exploring quantitative univariate variables**, looking for unexpected internal distributions of variables, ouliers that can lead to wrong or misled interpretations and possible skewness in the distribution.
#
# In this same fashion, they are very useful to compare variables. When plotted together, two variables can show differences in their distribution, although their summary statistics might be similar to each other.

# %% [markdown]
# ## Example: GDP per Capita by continent
#
# In this example we will use an already prepared data set, available in [Gapminder webpage](https://www.gapminder.org/data/).
#
# This csv file consists in information for almost all countries in the world with quinquennial time series from 1952 to 2007 and data for:country,year,population,continent,life Expectancy and GDP per Capita.
#
# For the purposes of this project, we will slice the information and select the most recent data (2007).
#
# In order to be able to compare variables, continent variable will be used for aggregation, resulting in 5 different sub-sets.
#
# The variable to analyse will be GDP Per Capita in USD.

# %%
import pandas as pd
data=pd.read_csv('data/gapminder-FiveYearData.csv')
data2007=data[data['year']==2007]

import matplotlib.pyplot as plt
data2007.boxplot(by='continent', column=['gdpPercap'])

# %% [markdown]
# ## Analysis
#
# Several steps should be performed when analysing boxplots in order to extract all its possibilities and to summarise all characteristics of this plot, as deecribed in this notebook.
#
# ### Centre and Spread
# Americas and espcially Oceania both show a quite symmetrical distribution, although their values are visibly different. Americas present a median (Q2) practically in the middle of the box, slightly lower than 10,000 USD, while minimum is close to 0 and maximum slighlty below 20,000 USD. This is consistent with the aforemaentioned symmetrical distribution.
#
# On the other hand, Asia represents the opposite situation, where the box is quite long, maximum value is far away from the box and the median lies in the bottom side of the box. It is a widely spread distribution with an asymmetric distribution.
#
# ### Skewness
#
# In relation with the previous paragraph, Oceania presents no skewness, while Asia is strongly skewed, since its asymmetrycal distribution shows large inequalities in regard to GDP per Capita. This shows wide internal variation and, therefore, aggregate analysis could be misleading and poorly represent the high variation of this population.
#
# ### Outliers
#
# In this boxplot we can only find two subsets with outliers. Africa and Americas both show extreme values that could be 'pulling' the box to the top. I would suggest that Americas' two outliers would represent USA and Canada, with much higher GDPs than the rest of the Americas. Thus, the symmetry showed in the boxplot could be forced by the presence of these two extremely high results in comparison with the rest of the subset.
# A methodological suggestion for researchers should be to delve further into this data and probably analyse South and Central America separatedely from North America, since aggregated analysis could be overestimated by the presence of this values.
#
# Similiarlly, althoug overall values in Africa are very low compared to the other continents, the presence of upper outliers could be making overall representation overestimated.
#
# ### Comparison
#
# As already has been stated, there very clear differences between groups represented in this plot. Further for what has already been established, it is interesting to note that Oceania and Europe present similar median values, close to 30,000 USD. However, regarding the spread we can see that Oceania is an overall balanced distribution, whereas Europe is widely spread, with minimum value around 8,000 USD and maximum very close to 50,000, which is the highest value in the whole data set. This is probably due to the amount and diversity of countries in Europe compared to that of Oceania.

# %% [markdown]
# # Alternatives to boxplot
#
# According to the literature, and specifically based in the aforementioned paper by Hadley Wickham and Lisa Stryjewski [40 years of boxplots](http://vita.had.co.nz/papers/boxplots.pdf), the alternatives, or the evolution of boxplot, concerns the represntation of density.
#
# In this paper the authors describe and analyse different plots that stress their ability to represent more complex information about the distribution, maintaing the compact size of the boxplot. These plots can overcome problems in the original such as the failure to display multi-modality, or the excessive number of “outliers” when n is large.
#
# ## Vase plot
# This plot displays a representation of density by replacing the box figure by a symmetrical density display.

# %% [markdown]
# ![box_plot-04.png](attachment:box_plot-04.png)

# %% [markdown]
# ## Violin plot
# Similar to vase plot, also attempting to represent density, which the original boxplot fails to display. In this case, unlike vase plot, density representation is not symmetrical.

# %% [markdown]
# ![proxy.duckduckgo.com.png](attachment:proxy.duckduckgo.com.png)

# %% [markdown]
# ## Bean plot
#
# The Beanplot shows the actual density curve, which is more informative than the information displayed by boxplot.
#
# The shape is the density, the longer thick lines are the mean (or optionally median) for each bean. The longer thin lines are the data, with a sort of "stacking" where wider lines indicate more duplicate values.
#
# The name is inspired by the appearance of the plot: the shape of the density looks like the outside of a bean pod, and the rug plot looks like the seeds within.

# %% [markdown]
# ![bean.jpg](attachment:bean.jpg)

# %% [markdown]
# ## Histograms
#
# Although histograms have less analytical capabilities than all plots shown so far, this is still a widely-used univariate graphical representation and should not be underestimated, both for its straightforward interpretation and omnipresence in analytical literatura, as well as for the general public.
#
# This plot lacks most of the boxplot features, as the centrality, spread, outlier and skewness detection. Still, sometimes, as we have seen throughout this course, it is the simpler, faster and most understandable graphical representation of a variable.

# %%
y=np.random.randn(125)
print(y)
plt.hist(y)
# Out:
# [-2.42626182  0.65812623  0.79743133  1.33265286 -0.26408914  0.55598643
#   1.11848257  0.51400811  2.21088352 -0.42856944  1.86734095  0.2271416
#   0.05010813  1.03041983 -1.60524535  0.07724069 -0.89726875 -0.28188569
#   1.83039131  1.87222217 -0.50177343 -0.84126924  1.78058199  1.54483215
#   0.03998131  0.23297571  0.10467292 -0.30895387  0.18453606  0.80819236
#   0.44754683 -1.02193464  0.68010969 -0.21632822 -1.09671608 -0.08509789
#   1.1252922  -0.17368438  0.18187569  0.20720857 -1.11790309 -0.93904644
#  -1.29040792 -0.8553774   0.25262235 -0.72306974  0.77101014 -0.12514006
#   1.26949464  1.00743756 -0.06605774  0.03315529 -1.06125968  0.28010655
#   0.47017014 -0.43600348  0.96873211 -0.98821125  0.51868325  1.40586822
#  -0.5718104   0.7157173   2.04256112 -0.44050529 -0.28038169  0.04281353
#   1.00263473  0.0045012   0.82237561 -1.2115265  -0.5556311   0.52549456
#  -0.74649881 -0.53207329  0.55229347 -0.09739191 -1.26382962 -0.31231654
# ...
